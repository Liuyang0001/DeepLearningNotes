# %% [markdown]
# ## Matplotlib
# 在深度学习的实验中，图形的绘制和数据的可视化非常重要。Matplotlib是用于绘制图形的库，使用Matplotlib 可以轻松地绘制图形和实现数据的可视化。

# %% [markdown]
# ### 绘制简单图形

# %%
import numpy as np
import matplotlib.pyplot  as plt

# 生成数据
x = np.arange(0,6,0.1)
y1 = np.sin(x)
y2 = np.cos(x)
# print(x,y)

# %%
# 绘制正弦曲线-实线-蓝色
plt.plot(x,y1,label="sin",linestyle="-",color="blue")
# 绘制余弦曲线-虚线-绿色
plt.plot(x,y2,label="cos",linestyle="--",color="green")
# 设置坐标轴便签
plt.xlabel("x") 
plt.ylabel("y")
plt.title("sin & cos") # 图像标题
plt.legend() # 添加图示
plt.show()

# %% [markdown]
# ### 显示图像

# %%
from matplotlib.image import imread
img = imread("lena.png")
plt.imshow(img)
plt.show()
